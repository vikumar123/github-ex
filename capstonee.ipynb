# %%
import sys
import requests
import json

import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors


import io
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

from sklearn.cluster import KMeans

# %% [markdown]
# All the files are imported...

# %%
df=pd.read_excel('highest_grossing_movies.xlsx')
df=df.dropna(subset=['Rank'])
df
# Out:
#     Rank                         Title Worldwide gross    Year
# 1    1.0            Gone with the Wind      3713000000  1939.0
# 2    2.0                        Avatar      3263000000  2009.0
# 3    3.0                       Titanic      3087000000  1997.0
# 4    4.0                     Star Wars      3049000000  1977.0
# 5    5.0             Avengers: Endgame      2798000000  2019.0
# 6    6.0            The Sound of Music      2554000000  1965.0
# 7    7.0    E.T. the Extra-Terrestrial      2493000000  1982.0
# 8    8.0          The Ten Commandments      2361000000  1956.0
# 9    9.0                Doctor Zhivago      2238000000  1965.0
# 10  10.0  Star Wars: The Force Awakens      2206000000  2015.0

# %% [markdown]
# This is the list of the highest grossing movies in U.S...now lets have a battle of genres... lets see the most popular genre in some countries of this world...and see which genre has the most popularity..so first listing out the highest grossing movies in different genres:

# %% [markdown]
# First we will emphasize on the top 50 action movies and how much they earned in the box office:

# %%
df_action=pd.read_excel('action.xlsx')
df_action
# Out:
#     Rank                                 Film  Worldwide gross    Year
# 0      1                    Avengers: Endgame       2797800564  2019.0
# 1      2               Avengers: Infinity War       2048359754  2018.0
# 2      3                         The Avengers       1518812988  2012.0
# 3      4              Avengers: Age of Ultron       1405403694  2015.0
# 4      5                        Black Panther       1346913171  2018.0
# 5      6                        Incredibles 2       1242805359     NaN
# 6      7                           Iron Man 3       1214811252  2013.0
# 7      8           Captain America: Civil War       1153304495  2016.0
# 8      9                              Aquaman       1148161807  2018.0
# 9     10            Spider-Man: Far From Home       1131927996  2019.0
# 10    11                       Captain Marvel       1128274794     NaN
# 11    12                The Dark Knight Rises       1081041287  2012.0
# 12    13                               Joker        1074251311  2019.0
# 13    14                      The Dark Knight       1004558444  2008.0
# 14    15                         Spider-Man 3        890871626  2007.0
# 15    16               Spider-Man: Homecoming        880166924  2017.0
# 16    17   Batman v Superman: Dawn of Justice        873634919  2016.0
# 17    18       Guardians of the Galaxy Vol. 2        863756051  2017.0
# 18    19                                Venom        856085151  2018.0
# 19    20                       Thor: Ragnarok        853977126  2017.0
# 20    21                         Wonder Woman        821847012  2017.0
# 21    22                           Spider-Man        821708551  2002.0
# 22    23                         Spider-Man 2        788976453  2004.0
# 23    24                           Deadpool 2        785046920  2018.0
# 24    25                             Deadpool        783112979  2016.0
# 25    26              Guardians of the Galaxy        773328629  2014.0
# 26    27               The Amazing Spider-Man        757930663  2012.0
# 27    28           X-Men: Days of Future Past        747862775  2014.0
# 28    29                        Suicide Squad        746846894  2016.0
# 29    30  Captain America: The Winter Soldier        714421503  2014.0
# 30    31             The Amazing Spider-Man 2        708982323     NaN
# 31    32                       Doctor Strange        677718395  2016.0
# 32    33                         Man of Steel        668045518  2013.0
# 33    34                       Justice League        657924295  2017.0
# 34    35                           Big Hero 6        657818612  2014.0
# 35    36                 Thor: The Dark World        644571402  2013.0
# 36    37                      The Incredibles        633019734  2004.0
# 37    38                              Hancock        624386746  2008.0
# 38    39                           Iron Man 2        623933331  2010.0
# 39    40                 Ant-Man and the Wasp        622674139  2018.0
# 40    41                                Logan        619021436  2017.0
# 41    42                             Iron Man        585174222  2008.0
# 42    43                    X-Men: Apocalypse        543934787  2016.0
# 43    44                              Ant-Man        519311965  2015.0
# 44    45         Teenage Mutant Ninja Turtles        493333584  2014.0
# 45    46                X-Men: The Last Stand        459359555  2006.0
# 46    47                                 Thor        449326618  2011.0
# 47    48                        The Wolverine        414828246  2013.0
# 48    49                               Batman        411556825  1989.0
# 49    50                                   X2        407711549  2003.0

# %%
import seaborn as sn
df_new=df_action[['Year','Worldwide gross']].transpose()
fig, ax = plt.subplots(figsize=(25,25))
sn.barplot(x='Year',y='Worldwide gross',data=df_action,ax=ax)

# %% [markdown]
# So from the above bar plot we can see that 2019 was the best year for super hero movies.Now lets move on to science fiction movies

# %%
df_science=pd.read_excel('science.xlsx')
df_science
# Out:
#     Rank                                          Film  Worldwide gross  Year
# 0      1                             Avengers: Endgame       2797800564  2019
# 1      2                                        Avatar       2789679794  2009
# 2      3                  Star Wars: The Force Awakens       2068223624  2015
# 3      4                        Avengers: Infinity War       2048359754  2018
# 4      5                                Jurassic World       1671713208  2015
# 5      6                                  The Avengers       1518812988  2012
# 6      7                       Avengers: Age of Ultron       1405403694  2015
# 7      8                                 Black Panther       1346913161  2018
# 8      9                      Star Wars: The Last Jedi       1332539889  2017
# 9     10                Jurassic World: Fallen Kingdom       1308467944  2018
# 10    11                                    Iron Man 3       1214811252  2013
# 11    12                    Captain America: Civil War       1153304495  2016
# 12    13                                       Aquaman       1148161807  2018
# 13    14                     Spider-Man: Far From Home       1131927996  2019
# 14    15                                Captain Marvel       1128274794  2019
# 15    16                Transformers: Dark of the Moon       1123794079  2011
# 16    17               Transformers: Age of Extinction       1104054072  2014
# 17    18             Star Wars: The Rise of Skywalker        1074144248  2019
# 18    19                                     Rogue One       1056057273  2016
# 19    20                                 Jurassic Park       1029939903  1993
# 20    21     Star Wars: Episode I – The Phantom Menace       1027044677  1999
# 21    22                                  Spider-Man 3        890871626  2007
# 22    23                        Spider-Man: Homecoming        880166924  2017
# 23    24            Batman v Superman: Dawn of Justice        873634919  2016
# 24    25               The Hunger Games: Catching Fire        865011746  2013
# 25    26                 Guardians of the Galaxy Vol 2        863756051  2017
# 26    27                                         Venom        856085151  2018
# 27    28                                Thor: Ragnarok        853977126  2017
# 28    29  Star Wars: Episode III – Revenge of the Sith        848754768  2005
# 29    30           Transformers: Revenge of the Fallen        836303693  2009
# 30    31                                  Wonder Woman        821847012  2017
# 31    32                                    Spider-Man        821708551  2002
# 32    33                              Independence Day        817400891  1996
# 33    34                    E.T. the Extra-Terrestrial        792910554  1982
# 34    35                                    Deadpool 2        785046920  2018
# 35    36                                  Spider-Man 2        783766341  2004
# 36    37                                      Deadpool        783112979  2016
# 37    38                                     Star Wars        775398007  1977
# 38    39                       Guardians of the Galaxy        773328629  2014
# 39    40                        The Amazing Spider-Man        757930663  2012
# 40    41                    X-Men: Days of Future Past        747862775  2014
# 41    42                                 Suicide Squad        746846894  2016
# 42    43                           The Matrix Reloaded        741846459  2003
# 43    44                                       Gravity        723192705  2013
# 44    45           Captain America: The Winter Soldier        714264267  2014
# 45    46                Dawn of the Planet of the Apes        710644566  2014
# 46    47                                  Transformers        709709780  2007
# 47    48                      The Amazing Spider-Man 2        708982323  2014
# 48    49                           The Wandering Earth        699760773  2019
# 49    50                              The Hunger Games        694394724  2012

# %%
fig, ax = plt.subplots(figsize=(25,25))
df_science['Worldwide gross']=df_science['Worldwide gross'].astype('int')
sn.barplot(x='Year',y='Worldwide gross',data=df_science,ax=ax)

# %% [markdown]
# Well it seems like science fiction movies were most popular in the year 2009..Now lets move on to horror,comedy and animated movies...

# %%
df_horror=pd.read_excel('horror.xlsx')
df_horror
# Out:
#     Rank                                   Film  Worldwide gross  Year
# 0      1                                     It        700381748  2017
# 1      2                        The Sixth Sense        672806292  1999
# 2      3                      War of the Worlds        591745540  2005
# 3      4                            I Am Legend        585349010  2007
# 4      5                            World War Z        540007876  2013
# 5      6                                The Meg        530243742  2018
# 6      7                               Godzilla        529076069  2014
# 7      8                        It Chapter Two         473093228  2019
# 8      9                                   Jaws        470653000  1975
# 9     10                           The Exorcist        441306145  1973
# 10    11                      The Mummy Returns        433013274  2001
# 11    12                              The Mummy        415933406  1999
# 12    13                              The Mummy        409231607  2017
# 13    14                                  Signs        408247917  2002
# 14    15                             Prometheus        403354469  2012
# 15    16  The Mummy: Tomb of the Dragon Emperor        401128639  2008
# 16    17         Godzilla: King of the Monsters        385900138  2019
# 17    18                               Godzilla        379014294  1998
# 18    19                                The Nun        365550119  2018
# 19    20                               Hannibal        351692268  2001
# 20    21                          A Quiet Place        340939361  2018
# 21    22                        The Conjuring 2        320392818  2016
# 22    23                          The Conjuring        319494638  2013
# 23    24       Resident Evil: The Final Chapter        312242626  2017
# 24    25                    Annabelle: Creation        306515884  2017
# 25    26                            Van Helsing        300257475  2004
# 26    27               Resident Evil: Afterlife        300228084  2010
# 27    28                         Shutter Island        294804195  2010
# 28    29                                  Split        278454358  2017
# 29    30                            Scary Movie        278019771  2000
# 30    31               The Silence of the Lambs        272742922  1991
# 31    32                              Annabelle        257047661  2014
# 32    33                            The Village        256697520  2004
# 33    34                              Halloween        255498536  2018
# 34    35                                Get Out        255407663  2017
# 35    36                                     Us        254732150  2019
# 36    37                The Blair Witch Project        248639099  1999
# 37    38                               The Ring        248218486  2002
# 38    39                            Unbreakable        248118121  2000
# 39    40                                  Glass        246985576  2019
# 40    41                           Dark Shadows        245527149  2012
# 41    42                        Alien: Covenant        240891763  2017
# 42    43             Resident Evil: Retribution        240004424  2012
# 43    44                            Constantine        230884728  2005
# 44    45                   Annabelle Comes Home        228552591  2019
# 45    46             Interview with the Vampire        223664608  1994
# 46    47                          Scary Movie 3        220673217  2003
# 47    48                         Dracula Untold        217124280  2014
# 48    49                  Bram Stoker's Dracula        215862692  1992
# 49    50                            End of Days        211989043  1999

# %%
fig, ax = plt.subplots(figsize=(25,25))
df_horror['Worldwide gross']=df_horror['Worldwide gross'].astype('int')
sn.barplot(x='Year',y='Worldwide gross',data=df_horror,ax=ax)

# %% [markdown]
# well it seems like 2007 was the most popular year for horror movies.let's continue

# %%
df_comedy=pd.read_excel('comedy.xlsx')
df_comedy
# Out:
#     Rank                                   Film  Worldwide Gross  Year
# 0      1                          Incredibles 2       1242805359  2018
# 1      2                                Minions       1159398397  2015
# 2      3                        Despicable Me 3       1035799409  2017
# 3      4                        Despicable Me 2        970761885  2013
# 4      5                                Shrek 2        919800000  2004
# 5      6                The Secret Life of Pets        875457937  2016
# 6      7                        Shrek the Third        798958162  2007
# 7      8                             Deadpool 2        785046920  2018
# 8      9                               Deadpool        783112979  2016
# 9     10                    Shrek Forever After        752600867  2010
# 10    11     Madagascar 3: Europe's Most Wanted        746921274  2012
# 11    12                        The Incredibles        633019734  2004
# 12    13                         Men in Black 3        624026776  2012
# 13    14            Madagascar: Escape 2 Africa        603900354  2008
# 14    15                                Tangled        593171580  2010
# 15    16                           Men in Black        589390539  1997
# 16    17                   The Hangover Part II        586764305  2011
# 17    18                                 Cars 2        562110557  2011
# 18    19                          Puss in Boots        554987477  2011
# 19    20                                    Ted        549368315  2012
# 20    21                          Despicable Me        543113985  2010
# 21    22                             Madagascar        532680671  2005
# 22    23              Ralph Breaks the Internet        529323962  2018
# 23    24  Hotel Transylvania 3: Summer Vacation        528583774  2018
# 24    25                     The Simpsons Movie        527071022  2007
# 25    26                       Meet the Fockers        522657936  2004
# 26    27                       The Intouchables        484873045  2011
# 27    28                         Bruce Almighty        484592874  2004
# 28    29                                  Shrek        484409218  2001
# 29    30                             Home Alone        477063114  1990
# 30    31                   Hotel Transylvania 2        474800000  2015
# 31    32                         Wreck-It Ralph        471222889  2012
# 32    33                           The Hangover        469310836  2009
# 33    34                         The Lego Movie        468060692  2014
# 34    35                                   Cars        461983149  2006
# 35    36                        Men in Black II        441818803  2002
# 36    37                         Mrs. Doubtfire        441286195  1993
# 37    38              The Secret Life of Pets 2        430051293  2019
# 38    39                       Sex and the City        418765321  2008
# 39    40                     Back to the Future        389053797  1985
# 40    41                                 Cars 3        383930656  2017
# 41    42                 Penguins of Madagascar        373515621  2015
# 42    43                                Shazam!        365971656  2019
# 43    44                  The Hangover Part III        362000072  2013
# 44    45         Home Alone 2: Lost in New York        358994850  1992
# 45    46                     Hotel Transylvania        358375603  2012
# 46    47                               Rain Man        354825435  1988
# 47    48                               The Mask        351583407  1994
# 48    49                        The Flintstones        341631208  1994
# 49    50                          Never Say Die        334530869  2017

# %%
fig, ax = plt.subplots(figsize=(25,25))
df_comedy['Worldwide Gross']=df_comedy['Worldwide Gross'].astype('int')
sn.barplot(x='Year',y='Worldwide Gross',data=df_comedy,ax=ax)

# %% [markdown]
# 2016 for comedy now lets move on to the last genre being evaluated in this battle:animation/live-action

# %%
df_anim=pd.read_excel('animation.xlsx')
df_anim
# Out:
#     Rank                                             Title  Worldwide gross  \
# 0      1                                        The Smurfs        563749323
# 1      2                                               Ted        549368315
# 2      3                      Teenage Mutant Ninja Turtles        493333584
# 3      4           Alvin and the Chipmunks: The Squeakquel        443140005
# 4      5                         Pokémon Detective Pikachu        431605346
# 5      6                           Alvin and the Chipmunks        361336633
# 6      7                                      Peter Rabbit        351266433
# 7      8                              Mary Poppins Returns        349537494
# 8      9                                      The Smurfs 2        347545360
# 9     10              Alvin and the Chipmunks: Chipwrecked        342695435
# 10    11                                         Enchanted        340487652
# 11    12                           Who Framed Roger Rabbit        329803958
# 12    13                               Sonic the Hedgehog         306766470
# 13    14                                     Stuart Little        300135367
# 14    15                                           G-Force        292817841
# 15    16                                            Casper        287928194
# 16    17                                        Scooby-Doo        275650703
# 17    18                                        Paddington        268047808
# 18    19  Teenage Mutant Ninja Turtles: Out of the Shadows        245623848
# 19    20            Alvin and the Chipmunks: The Road Chip        234798636
# 20    21                                         Space Jam        230418342
# 21    22                                      Paddington 2        224353866
# 22    23                                             Ted 2        213734783
# 23    24                                         Yogi Bear        201584141
# 24    25                                          Garfield        200804534
# 25    26                                 Christopher Robin        197744377
# 26    27                                               Hop        183953723
# 27    28                                           The BFG        183345589
# 28    29                  Scooby-Doo 2: Monsters Unleashed        180949045
# 29    30                                   Stuart Little 2        169956806
# 30    31                                   Charlotte's Web        144877632
# 31    32                                     Pete's Dragon        143695338
# 32    33                   Garfield: A Tail of Two Kitties        141702264
# 33    34                            Walking with Dinosaurs        126546518
# 34    35                    Dora and the Lost City of Gold        119682635
# 35    36                         Arthur and the Invisibles        107944236
# 36    37                             The Call of the Wild         107604626
# 37    38                                      Mary Poppins        103078700
# 38    39               Arthur and the Revenge of Maltazard         78520547
# 39    40                    Diary of a Wimpy Kid: Dog Days         77112176
# 40    41                              Diary of a Wimpy Kid         75700498
# 41    42               Diary of a Wimpy Kid: Rodrick Rules         72417394
# 42    43                      Looney Tunes: Back in Action         68514844
# 43    44                                 Song of the South         65000000
# 44    45                                    Monster Trucks         64493915
# 45    46                               Aliens in the Attic         57881056
# 46    47               Diary of a Wimpy Kid: The Long Haul         40140972
# 47    48                                     Pete's Dragon         39588000
# 48    49                          Bedknobs and Broomsticks         26100000
# 49    50                     Thomas and the Magic Railroad         19748009
#
#     Year
# 0   2011
# 1   2012
# 2   2014
# 3   2009
# 4   2019
# 5   2007
# 6   2018
# 7   2018
# 8   2013
# 9   2011
# 10  2007
# 11  1988
# 12  2020
# 13  1999
# 14  2009
# 15  1995
# 16  2002
# 17  2014
# 18  2016
# 19  2015
# 20  1996
# 21  2017
# 22  2015
# 23  2010
# 24  2004
# 25  2018
# 26  2011
# 27  2016
# 28  2004
# 29  2002
# 30  2006
# 31  2016
# 32  2006
# 33  2013
# 34  2019
# 35  2006
# 36  2020
# 37  1964
# 38  2009
# 39  2012
# 40  2010
# 41  2011
# 42  2003
# 43  1946
# 44  2016
# 45  2009
# 46  2017
# 47  1977
# 48  1971
# 49  2000

# %%
fig, ax = plt.subplots(figsize=(25,25))
df_anim['Worldwide gross']=df_anim['Worldwide gross'].astype('int')
sn.barplot(x='Year',y='Worldwide gross',data=df_anim,ax=ax)

# %% [markdown]
# Hmmm....2014 was very popular for animation...Now lets head on to find out which genre is the most popular

# %%
max_action=df_action['Worldwide gross'].astype('int').max()
max_science=df_science['Worldwide gross'].astype('int').max()
max_horror=df_horror['Worldwide gross'].astype('int').max()
max_comedy=df_comedy['Worldwide Gross'].astype('int').max()
max_anim=df_anim['Worldwide gross'].astype('int').max()

# %%
dictionary=dict()
dictionary={'genre':['action','science','horror','comedy','anim'],'gross values':[max_action,max_science,max_horror,max_comedy,max_anim]}

# %%
df_tot=pd.DataFrame(dictionary)
df_tot
# Out:
#      genre  gross values
# 0   action    2797800564
# 1  science    2797800564
# 2   horror     700381748
# 3   comedy    1242805359
# 4     anim     563749323

# %%
sn.barplot(x='genre',y='gross values',data=df_tot)

# %% [markdown]
# So according to our study action and science movies have the most popularity in today's world,whereas animation doesn't have much popularity

# %% [markdown]
# Ok now let's find out in U.S which cities there are the most number of theatres...from this information we can find out in which city movies are the most popular when they are released..lets look at the data's of some of the cities with Foursquare API...

# %%
CLIENT_ID='T0DZHOX10FDX5ZZNKQLIVGLHYQAVFOGIM1QRJZN3Q3U0QOJE'
CLIENT_SECRET='0PL015D4N4Z2URPN0VGMPE3NJ5JEW2AJZSXN0GOZOW0GURK0'
VERSION=20200201

# %%
radius = 1000
LIMIT = 100

def getNearbyVenues(names, latitudes, longitudes, radius=1000):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['District', 
                  'Dist_Latitude', 
                  'Dist_Longitude', 
                  'Venue', 
                  'Venue_Lat', 
                  'Venue_Long', 
                  'Venue_Category']
    
    return(nearby_venues)

# %% [markdown]
# Ok...first lets find out the most popular cities in the United states then we will find out the number of theatres in each of those cities

# %%
# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     geopy-1.21.0               |             py_0          58 KB  conda-forge
#     openssl-1.1.1g             |       h516909a_0         2.1 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   geographiclib      conda-forge/noarch::geographiclib-1.50-py_0
#   geopy              conda-forge/noarch::geopy-1.21.0-py_0
#
# The following packages will be UPDATED:
#
#   openssl                                 1.1.1f-h516909a_0 --> 1.1.1g-h516909a_0
#
#
#
# Downloading and Extracting Packages
# openssl-1.1.1g       | 2.1 MB    | ##################################### | 100%
# geopy-1.21.0         | 58 KB     | ##################################### | 100%
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
geolocator = Nominatim()
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Using Nominatim with the default "geopy/1.21.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   """Entry point for launching an IPython kernel.

# %%
df_country=pd.read_excel('most_popular_countries.xlsx')
df_country=df_country.dropna(subset=['City'])
df_top_20=df_country.head(20)

# %%
lst=df_top_20['City'].to_list()
lst
# Out:
# ['New York',
#  'Los Angeles',
#  'Chicago',
#  'Houston',
#  'Phoenix',
#  'Philadelphia',
#  'San Antonio',
#  'San Diego',
#  'Dallas',
#  'San Jose',
#  'Austin',
#  'Jacksonville',
#  'Fort Worth',
#  'Columbus',
#  'San Francisco',
#  'Charlotte',
#  'Indianapolis',
#  'Seattle',
#  'Denver',
#  'Washington']

# %%
latitude=list()
longitude=list()
for itm in lst:
    locatn = geolocator.geocode(itm)
    latitude.append(locatn.latitude)
    longitude.append(locatn.longitude)

# %%
df_top_20['Latitude']=latitude
df_top_20['Longitude']=longitude
df_top_20
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    2018 rank           City 2018 estimate   Latitude   Longitude
# 1          1       New York       8398748  40.712728  -74.006015
# 2          2    Los Angeles       3990456  34.053691 -118.242767
# 3          3        Chicago       2705994  41.875562  -87.624421
# 4          4        Houston       2325502  29.758938  -95.367697
# 5          5        Phoenix       1660272  33.448437 -112.074142
# 6          6   Philadelphia       1584138  39.952724  -75.163526
# 7          7    San Antonio       1532233  29.424600  -98.495141
# 8          8      San Diego       1425976  32.717421 -117.162771
# 9          9         Dallas       1345047  32.776272  -96.796856
# 10        10       San Jose       1030119  37.336191 -121.890583
# 11        11         Austin        964254  30.271129  -97.743700
# 12        12   Jacksonville        903889  30.332184  -81.655651
# 13        13     Fort Worth        895008  32.753177  -97.332746
# 14        14       Columbus        892533  39.962260  -83.000707
# 15        15  San Francisco        883305  37.779026 -122.419906
# 16        16      Charlotte        872498  35.227087  -80.843127
# 17        17   Indianapolis        867125  39.768333  -86.158350
# 18        18        Seattle        744955  47.603832 -122.330062
# 19        19         Denver        716492  39.739236 -104.984862
# 20        20     Washington        702455  38.894985  -77.036571

# %% [markdown]
# So the above are the popular 20 cities in New York now let's find out the number of movie theatres in the above cities

# %%
top_20_city_theatres = getNearbyVenues(names=df_top_20['City'],
                                   latitudes=df_top_20['Latitude'],
                                   longitudes=df_top_20['Longitude']
                                  )
# Out:
# New York
# Los Angeles
# Chicago
# Houston
# Phoenix
# Philadelphia
# San Antonio
# San Diego
# Dallas
# San Jose
# Austin
# Jacksonville
# Fort Worth
# Columbus
# San Francisco
# Charlotte
# Indianapolis
# Seattle
# Denver
# Washington

# %%
top_20_city_theatres.head()
top_20_temp=top_20_city_theatres
top_20_temp
# Out:
#         District  Dist_Latitude  Dist_Longitude  \
# 0       New York      40.712728      -74.006015
# 1       New York      40.712728      -74.006015
# 2       New York      40.712728      -74.006015
# 3       New York      40.712728      -74.006015
# 4       New York      40.712728      -74.006015
# ...          ...            ...             ...
# 1988  Washington      38.894985      -77.036571
# 1989  Washington      38.894985      -77.036571
# 1990  Washington      38.894985      -77.036571
# 1991  Washington      38.894985      -77.036571
# 1992  Washington      38.894985      -77.036571
#
#                                                   Venue  Venue_Lat  \
# 0                          The Bar Room at Temple Court  40.711448
# 1                         The Beekman, A Thompson Hotel  40.711173
# 2                             Alba Dry Cleaner & Tailor  40.711434
# 3                                        City Hall Park  40.712415
# 4                             The Class by Taryn Toomey  40.712753
# ...                                                 ...        ...
# 1988                                       Tonic Lounge  38.898201
# 1989                                          Starbucks  38.903027
# 1990                                       Rawlins Park  38.895669
# 1991  The George Washington University Museum | The ...  38.898494
# 1992                                  State Plaza Hotel  38.896229
#
#       Venue_Long        Venue_Category
# 0     -74.006802             Hotel Bar
# 1     -74.006702                 Hotel
# 2     -74.006272       Laundry Service
# 3     -74.006724                  Park
# 4     -74.008734  Gym / Fitness Center
# ...          ...                   ...
# 1988  -77.046554                   Bar
# 1989  -77.031708           Coffee Shop
# 1990  -77.042327                 Plaza
# 1991  -77.046406        History Museum
# 1992  -77.047521                 Hotel
#
# [1993 rows x 7 columns]

# %%
top_20_aa = top_20_temp[top_20_temp['Venue_Category'].str.contains('Movie Theater')].reset_index(drop=True)

# %%
top_20_aa
# Out:
#          District  Dist_Latitude  Dist_Longitude  \
# 0         Phoenix      33.448437     -112.074142
# 1    Philadelphia      39.952724      -75.163526
# 2          Dallas      32.776272      -96.796856
# 3          Austin      30.271129      -97.743700
# 4          Austin      30.271129      -97.743700
# 5          Austin      30.271129      -97.743700
# 6      Fort Worth      32.753177      -97.332746
# 7        Columbus      39.962260      -83.000707
# 8   San Francisco      37.779026     -122.419906
# 9       Charlotte      35.227087      -80.843127
# 10     Washington      38.894985      -77.036571
#
#                                    Venue  Venue_Lat  Venue_Long  \
# 0                  AMC Arizona Center 24  33.453572 -112.069194
# 1               Philadelphia Film Center  39.950835  -75.164683
# 2                Alamo Drafthouse Cinema  32.769801  -96.799298
# 3                      Paramount Theatre  30.269457  -97.742077
# 4                Alamo Drafthouse Cinema  30.267460  -97.739550
# 5                    Violet Crown Cinema  30.265524  -97.748189
# 6                           AMC Palace 9  32.755499  -97.329827
# 7            COSI Extreme Screen Theater  39.959747  -83.006626
# 8                     Opera Plaza Cinema  37.781445 -122.421277
# 9   IMAX Dome Theater at Discovery Place  35.229688  -80.841768
# 10            Landmark's E Street Cinema  38.896200  -77.026805
#
#          Venue_Category
# 0         Movie Theater
# 1         Movie Theater
# 2         Movie Theater
# 3         Movie Theater
# 4         Movie Theater
# 5   Indie Movie Theater
# 6         Movie Theater
# 7         Movie Theater
# 8   Indie Movie Theater
# 9         Movie Theater
# 10  Indie Movie Theater

# %% [markdown]
# so those are the list of movie theaters in our top 20 cities now lets draw a map to find out which city has the most number of theaters:

# %%
import folium
rainbow = '#00ff00'
map_theater = folium.Map(location=(37.0902405, -95.7128906))

# %%
rainbow = '#00ff00'
map_t = folium.Map(location=(37.0902405, -95.7128906))
for lat,lon,ven,dist in zip(top_20_aa['Venue_Lat'],top_20_aa['Venue_Long'],top_20_aa['Venue'],top_20_aa['District']):
   
    folium.features.Marker(
        [lat,lon],
        
        
        ).add_to(map_t)
map_t
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df_1=top_20_aa[['District','Dist_Latitude']]
df_1=df_1.groupby(['District'],as_index=False).count()
df_1=df_1.rename(columns={'Dist_Latitude':'Count'})
df_1
# Out:
#         District  Count
# 0         Austin      3
# 1      Charlotte      1
# 2       Columbus      1
# 3         Dallas      1
# 4     Fort Worth      1
# 5   Philadelphia      1
# 6        Phoenix      1
# 7  San Francisco      1
# 8     Washington      1

# %%
sn.barplot(x='District',y='Count',data=df_1)

# %% [markdown]
# So the maximum number of theatres are in Austin and the most famous genre is action and science fiction.
